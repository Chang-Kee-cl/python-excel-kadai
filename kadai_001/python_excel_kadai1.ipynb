# %%
import openpyxl
from datetime import date

workbook = openpyxl.Workbook()

sheet = workbook.create_sheet('Sheet1')

today = date.today()

ws = workbook.active
ws['B2'] = '請求書'
ws['B4'] = 'ABC商会'
ws['B5'] = '〒101-0022 東京都千代田区神田練塀町300'
ws['B6'] = 'TEL:03-1234-5678 FAX:03-1234-5678'
ws['B7'] = '担当者名:鈴木一郎 様'

ws['F4'] = 'No.'
ws['G4'] = '0001'
ws['F5'] = '日付'
ws['G5'] = f'{today.strftime('%Y/%m/%d')}'

cell = ws.cell(row=9, column=1)

header = ['','商品名','数量','単価','金額']
ws.append(header)

date = [
    ['','商品A',2,10000,'=C11*D11'],
    ['','商品B',1,15000,'=C12*D12'],
    ['','','','','=SUM(E11:E12)']
]

for row in date:
    ws.append(row)

ws['B15'] = '合計'
ws['B16'] = '消費税'
ws['B17'] = '税込合計'
ws['E15'] = '=E13'
ws['E16'] = '=E15*10%'
ws['E17'] = '=SUM(E15:E16)'

workbook.save('請求書_20260818.xlsx')
